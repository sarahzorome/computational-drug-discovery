# %% [markdown]
# # **Computational Drug Discovery - Bioactivity Data**
#
# In this project, I will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, I will be performing data collection and pre-processing from the ChEMBL Database.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of Oct 29, 2023; ChEMBL version 33].

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for target protein**

# %% [markdown]
# ### **Target search for sodium/glucose cotransporter 2 (SGLT2)**

# %%
# Target search for SGLT2
target = new_client.target
target_query = target.search('SGLT2')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P31639', 'xref_name': None, 'xre...       Homo sapiens
# 1  [{'xref_id': 'Q923I7', 'xref_name': None, 'xre...       Mus musculus
# 2  [{'xref_id': 'P53792', 'xref_name': None, 'xre...  Rattus norvegicus
#
#                         pref_name  score  species_group_flag target_chembl_id  \
# 0  Sodium/glucose cotransporter 2   18.0               False       CHEMBL3884
# 1  Sodium/glucose cotransporter 2   17.0               False    CHEMBL1075302
# 2  Sodium/glucose cotransporter 2   14.0               False       CHEMBL4316
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P31639', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'Q923I7', 'component_descriptio...  SINGLE PROTEIN   10090
# 2  [{'accession': 'P53792', 'component_descriptio...  SINGLE PROTEIN   10116

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human SGLT2* (first entry)**

# %% [markdown]
# I will assign the first entry (which corresponds to the target protein, *Human SGLT2*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL3884'

# %% [markdown]
# Here, I will retrieve only bioactivity data for *Human SGLT2* (CHEMBL3884) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1579  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1580  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1581  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1582  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1583  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# ...

# %%
df.to_csv('../data/SGLT2_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /var/folders/0b/t44sb5395fz_lr8c2gy7h3h80000gn/T/ipykernel_15443/3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1579  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1580  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1581  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1298

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1560  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1562  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1563  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1565  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1575  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# Combine the 3 columns (molecule_chembl_id, canonical_smiles, standard_value) and bioactivity_class into a DataFrame

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL183937  Cc1cc(O)c(C(=O)CCc2ccc3occc3c2)c(O[C@@H]2O[C@H...
# 1          CHEMBL371448  Cc1cc(O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]...
# 2          CHEMBL382302  Cc1cc(O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]...
# 3          CHEMBL382319  CCc1cc(O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H...
# 4          CHEMBL200608  Cc1cc(O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]...
# ...                 ...                                                ...
# 1560      CHEMBL5177502  OC[C@H]1O[C@@H](c2ccc(Cl)c(Cc3ccc(OC4CCOC4)cc3...
# 1562      CHEMBL5202047  CCOc1ccc(Cc2cc([C@H]3O[C@@H](SC)[C@H](O)[C@@H]...
# 1563      CHEMBL5182632  COc1ccc(Cc2cc([C@H]3O[C@@H](SC)[C@H](O)[C@@H](...
# 1565      CHEMBL5205876  COc1ccc(Cc2cc3c(c([C@@H]4O[C@H](CO)[C@@H](O)[C...
# 1575      CHEMBL5208827  Cc1ccc(Cc2cc([C@@H]3O[C@H](CO)[C@@H](O)[C@H](O...
#
#      standard_value
# 0              11.0
# 1             491.0
# ...

# %%
df3.to_csv('../data/SGLT2_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('SGLT2_02_bioactivity_data_preprocessed.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/sarahzorome/Desktop/bioinformatics_cdd/notebooks/CDD_ML_Part_1_SGLT2_Bioactivity_Data.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/Users/sarahzorome/Desktop/bioinformatics_cdd/notebooks/CDD_ML_Part_1_SGLT2_Bioactivity_Data.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> df4 = pd.read_csv('SGLT2_02_bioactivity_data_preprocessed.csv')
#
# ...

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL183937  Cc1cc(O)c(C(=O)CCc2ccc3occc3c2)c(O[C@@H]2O[C@H...
# 1          CHEMBL371448  Cc1cc(O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]...
# 2          CHEMBL382302  Cc1cc(O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]...
# 3          CHEMBL382319  CCc1cc(O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H...
# 4          CHEMBL200608  Cc1cc(O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]...
# ...                 ...                                                ...
# 1293      CHEMBL5177502  OC[C@H]1O[C@@H](c2ccc(Cl)c(Cc3ccc(OC4CCOC4)cc3...
# 1294      CHEMBL5202047  CCOc1ccc(Cc2cc([C@H]3O[C@@H](SC)[C@H](O)[C@@H]...
# 1295      CHEMBL5182632  COc1ccc(Cc2cc([C@H]3O[C@@H](SC)[C@H](O)[C@@H](...
# 1296      CHEMBL5205876  COc1ccc(Cc2cc3c(c([C@@H]4O[C@H](CO)[C@@H](O)[C...
# 1297      CHEMBL5208827  Cc1ccc(Cc2cc([C@@H]3O[C@H](CO)[C@@H](O)[C@H](O...
#
#       standard_value   class
# 0              11.00  active
# ...

# %%
df5.to_csv('../data/SGLT2_03_bioactivity_data_curated.csv', index=False)

# %%
! zip SGLT2.zip *.csv
# Out:
#   adding: SGLT2_01_bioactivity_data_raw.csv (deflated 93%)
#   adding: SGLT2_02_bioactivity_data_preprocessed.csv (deflated 86%)
#   adding: SGLT2_03_bioactivity_data_curated.csv (deflated 87%)

# %%
! ls -l
# Out:
# total 4000
# -rw-r--r--@ 1 sarahzorome  staff   128951 Oct 30 18:28 CDD_ML_Part_1_SGLT2_Bioactivity_Data.ipynb
# -rw-r--r--@ 1 sarahzorome  staff   293601 Oct 30 20:17 CDD_ML_Part_2_SGLT2_Exploratory_Data_Analysis.ipynb
# -rw-r--r--  1 sarahzorome  staff   117885 Oct 30 21:11 SGLT2.zip
# -rw-r--r--  1 sarahzorome  staff  1235001 Oct 30 21:11 SGLT2_01_bioactivity_data_raw.csv
# -rw-r--r--  1 sarahzorome  staff   123003 Oct 30 21:11 SGLT2_02_bioactivity_data_preprocessed.csv
# -rw-r--r--  1 sarahzorome  staff   132719 Oct 30 21:11 SGLT2_03_bioactivity_data_curated.csv
# -rw-r--r--  1 sarahzorome  staff      286 Oct 30 20:54 test.ipynb

# %% [markdown]
# ---
